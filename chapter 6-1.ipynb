# %% [markdown]
# # DDQN(Double-DQN) 구현

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
import random
# %matplotlib inline

# %%
from collections import namedtuple
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99 # 시간 할인율
NUM_STEPS = 200
NUM_EPISODES = 500

# %%
class ReplayMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0
    
    def push(self, state, action, next_state, reward):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.index] = Transition(state, action, next_state, reward)
        self.index = (self.index + 1) % self.capacity
        
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
# 신경망 구성
from torch import nn
from torch.nn import functional as F

class Net(nn.Module):
    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_mid)
        self.fc4 = nn.Linear(n_mid, n_mid)
        self.fc5 = nn.Linear(n_mid, n_out)
        
    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        h3 = F.relu(self.fc3(h2))
        h4 = F.relu(self.fc4(h3))
        output = self.fc5(h4)
        return output

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        self.memory = ReplayMemory(CAPACITY) # transition을 기억하기 위한 메모리 객체 생성
        
        # 신경망 구성
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network) # 신경망 구조 출력
        
        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001) # 최적화 기법 선택
        
    def replay(self):
        if len(self.memory) < BATCH_SIZE: # 저장된 transition의 수를 확인
            return
        # Create Mini-batch
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()
        # Calculate Q(s_t, a_t) for answer signal
        self.expected_state_action_values = self.get_expected_state_action_values()
        # 결합 가중치 수정
        self.update_main_q_network()
        
    def decide_action(self, state, episode):
        epsilon = 0.5 * (1 / (episode + 1))
        if epsilon < np.random.uniform(0, 1): 
            self.main_q_network.eval()
            with torch.no_grad():
                action = self.main_q_network(state).max(axis=1)[1].reshape(1, 1)
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
            
        return action
    
    def make_minibatch(self):
        transition = self.memory.sample(BATCH_SIZE)
        batch = Transition(*zip(*transition)) # (state, action, next_state, reward) * batch_size ==> (state * batch_size, action * batch_size ...)으로 변경
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        
        return batch, state_batch, action_batch, reward_batch, non_final_next_states
    
    def get_expected_state_action_values(self):
        # 신경망을 추론 모드로 변경
        self.main_q_network.eval()
        self.target_q_network.eval()
        
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch) # Q_m(s_t, a_t)를 계산
        # next_state이 존재하는지를 확인하기 위한 인덱스 마스크 생성
        non_final_mask = torch.BoolTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))
        next_state_values = torch.zeros(BATCH_SIZE) # next_state의 값을 저장하기 위해 모두 0으로 초기화
        
        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)
        # a_m을 구하기 위해 main_q_network에 다음 state를 넘긴 출력 값인 Q_m(s_t+1, a)에서 detach()로 값을 때어낸 후 최댓값을 가지는 Q값의 인덱스를 추출함
        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(axis=1)[1]
        # a_m의 형태 변경 (size 1 ==> size 1*1)
        a_m_non_final_next_states = a_m[non_final_mask].reshape(-1, 1)
        # Target_q_network를 사용해서 최대가 되는 행동 a_m에서의 Q값을 구함
        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()
        
        # 계산
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values
        return expected_state_action_values
    
    def update_main_q_network(self):
        self.main_q_network.train() # 신경망을 학습 모드로 전환
        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))
        
        self.optimizer.zero_grad() # 경사를 초기화
        loss.backward() # 역전파 계산
        self.optimizer.step() # 결합 가중치 수정
        
    def update_target_q_network(self):
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        '''태스크의 상태 및 행동의 가짓수를 설정'''
        self.brain = Brain(num_states, num_actions)  # 에이전트의 행동을 결정할 두뇌 역할 객체를 생성

    def update_q_function(self):
        '''Q함수를 수정'''
        self.brain.replay()

    def get_action(self, state, episode):
        '''행동을 결정'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memory 객체에 state, action, state_next, reward 내용을 저장'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''Target Q-Network을 Main Q-Network와 맞춤'''
        self.brain.update_target_q_network()

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n
        self.agent = Agent(num_states, num_actions)
        
    def run(self):
        episode_10_list = np.zeros(10)
        complete_episodes = 0
        episode_final = False # 마지막 episode 여부
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)
            
            for step in range(NUM_STEPS):
                action = self.agent.get_action(state, episode)
                observation_next, _, done, _ = self.env.step(action.item())
                
                if done:
                    state_next = None
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes += 1
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                    
                self.agent.memorize(state, action, state_next, reward)
                self.agent.update_q_function() # Experience Replay로 Q함수 저장
                state = state_next # 관측 결과 update
                
                if done:
                    print('%d Episode: Finished after %d steps：최근 10 에피소드의 평균 단계 수 = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    if episode % 2 == 0:
                        self.agent.update_target_q_function()
                    break
            
            if episode_final is True:
                break
            if complete_episodes >= 10:
                print("10 에피소드 연속 성공")
                episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=32, bias=True)
#   (fc5): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 1.1
# 1 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 2.0
# 2 Episode: Finished after 11 steps：최근 10 에피소드의 평균 단계 수 = 3.1
# 3 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 4.1
# 4 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 5.0
# 5 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 6.2
# 6 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 7.1
# 7 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 8.0
# 8 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 8.9
# 9 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 10.3
# 10 Episode: Finished after 20 steps：최근 10 에피소드의 평균 단계 수 = 11.2
# 11 Episode: Finished after 22 steps：최근 10 에피소드의 평균 단계 수 = 12.5
# 12 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 12.8
# 13 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 12.7
# 14 Episode: Finished after 9 steps：최근 10 에피소드의 평균 단계 수 = 12.7
# 15 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 12.5
# 16 Episode: Finished after 10 steps：최근 10 에피소드의 평균 단계 수 = 12.6
# 17 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 13.4
# 18 Episode: Finished after 15 steps：최근 10 에피소드의 평균 단계 수 = 14.0
# 19 Episode: Finished after 16 steps：최근 10 에피소드의 평균 단계 수 = 14.2
# 20 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 14.9
# 21 Episode: Finished after 28 steps：최근 10 에피소드의 평균 단계 수 = 15.5
# 22 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 15.8
# 23 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 16.7
# 24 Episode: Finished after 17 steps：최근 10 에피소드의 평균 단계 수 = 17.5
# 25 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 17.9
# 26 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 18.7
# 27 Episode: Finished after 12 steps：최근 10 에피소드의 평균 단계 수 = 18.2
# 28 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 18.5
# 29 Episode: Finished after 14 steps：최근 10 에피소드의 평균 단계 수 = 18.3
# 30 Episode: Finished after 33 steps：최근 10 에피소드의 평균 단계 수 = 18.9
# 31 Episode: Finished after 19 steps：최근 10 에피소드의 평균 단계 수 = 18.0
# 32 Episode: Finished after 18 steps：최근 10 에피소드의 평균 단계 수 = 18.1
# 33 Episode: Finished after 26 steps：최근 10 에피소드의 평균 단계 수 = 18.9
# 34 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 19.5
# 35 Episode: Finished after 36 steps：최근 10 에피소드의 평균 단계 수 = 21.7
# 36 Episode: Finished after 29 steps：최근 10 에피소드의 평균 단계 수 = 22.8
# 37 Episode: Finished after 39 steps：최근 10 에피소드의 평균 단계 수 = 25.5
# 38 Episode: Finished after 48 steps：최근 10 에피소드의 평균 단계 수 = 28.5
# 39 Episode: Finished after 80 steps：최근 10 에피소드의 평균 단계 수 = 35.1
# 40 Episode: Finished after 44 steps：최근 10 에피소드의 평균 단계 수 = 36.2
# 41 Episode: Finished after 79 steps：최근 10 에피소드의 평균 단계 수 = 42.2
# 42 Episode: Finished after 43 steps：최근 10 에피소드의 평균 단계 수 = 44.7
# 43 Episode: Finished after 80 steps：최근 10 에피소드의 평균 단계 수 = 50.1
# 44 Episode: Finished after 34 steps：최근 10 에피소드의 평균 단계 수 = 51.2
# 45 Episode: Finished after 31 steps：최근 10 에피소드의 평균 단계 수 = 50.7
# 46 Episode: Finished after 34 steps：최근 10 에피소드의 평균 단계 수 = 51.2
# 47 Episode: Finished after 48 steps：최근 10 에피소드의 평균 단계 수 = 52.1
# 48 Episode: Finished after 53 steps：최근 10 에피소드의 평균 단계 수 = 52.6
# 49 Episode: Finished after 27 steps：최근 10 에피소드의 평균 단계 수 = 47.3
# 50 Episode: Finished after 23 steps：최근 10 에피소드의 평균 단계 수 = 45.2
# 51 Episode: Finished after 29 steps：최근 10 에피소드의 평균 단계 수 = 40.2
# 52 Episode: Finished after 25 steps：최근 10 에피소드의 평균 단계 수 = 38.4
# 53 Episode: Finished after 33 steps：최근 10 에피소드의 평균 단계 수 = 33.7
# 54 Episode: Finished after 36 steps：최근 10 에피소드의 평균 단계 수 = 33.9
# 55 Episode: Finished after 43 steps：최근 10 에피소드의 평균 단계 수 = 35.1
# 56 Episode: Finished after 88 steps：최근 10 에피소드의 평균 단계 수 = 40.5
# 57 Episode: Finished after 30 steps：최근 10 에피소드의 평균 단계 수 = 38.7
# 58 Episode: Finished after 60 steps：최근 10 에피소드의 평균 단계 수 = 39.4
# 59 Episode: Finished after 86 steps：최근 10 에피소드의 평균 단계 수 = 45.3
# 60 Episode: Finished after 93 steps：최근 10 에피소드의 평균 단계 수 = 52.3
# 61 Episode: Finished after 124 steps：최근 10 에피소드의 평균 단계 수 = 61.8
# 62 Episode: Finished after 51 steps：최근 10 에피소드의 평균 단계 수 = 64.4
# 63 Episode: Finished after 86 steps：최근 10 에피소드의 평균 단계 수 = 69.7
# 64 Episode: Finished after 43 steps：최근 10 에피소드의 평균 단계 수 = 70.4
# 65 Episode: Finished after 86 steps：최근 10 에피소드의 평균 단계 수 = 74.7
# 66 Episode: Finished after 70 steps：최근 10 에피소드의 평균 단계 수 = 72.9
# 67 Episode: Finished after 70 steps：최근 10 에피소드의 평균 단계 수 = 76.9
# 68 Episode: Finished after 52 steps：최근 10 에피소드의 평균 단계 수 = 76.1
# 69 Episode: Finished after 84 steps：최근 10 에피소드의 평균 단계 수 = 75.9
# 70 Episode: Finished after 107 steps：최근 10 에피소드의 평균 단계 수 = 77.3
# 71 Episode: Finished after 58 steps：최근 10 에피소드의 평균 단계 수 = 70.7
# 72 Episode: Finished after 112 steps：최근 10 에피소드의 평균 단계 수 = 76.8
# 73 Episode: Finished after 81 steps：최근 10 에피소드의 평균 단계 수 = 76.3
# 74 Episode: Finished after 52 steps：최근 10 에피소드의 평균 단계 수 = 77.2
# 75 Episode: Finished after 117 steps：최근 10 에피소드의 평균 단계 수 = 80.3
# 76 Episode: Finished after 54 steps：최근 10 에피소드의 평균 단계 수 = 78.7
# 77 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 85.0
# 78 Episode: Finished after 57 steps：최근 10 에피소드의 평균 단계 수 = 85.5
# 79 Episode: Finished after 133 steps：최근 10 에피소드의 평균 단계 수 = 90.4
# 80 Episode: Finished after 109 steps：최근 10 에피소드의 평균 단계 수 = 90.6
# 81 Episode: Finished after 136 steps：최근 10 에피소드의 평균 단계 수 = 98.4
# 82 Episode: Finished after 63 steps：최근 10 에피소드의 평균 단계 수 = 93.5
# 83 Episode: Finished after 70 steps：최근 10 에피소드의 평균 단계 수 = 92.4
# 84 Episode: Finished after 74 steps：최근 10 에피소드의 평균 단계 수 = 94.6
# 85 Episode: Finished after 127 steps：최근 10 에피소드의 평균 단계 수 = 95.6
# 86 Episode: Finished after 97 steps：최근 10 에피소드의 평균 단계 수 = 99.9
# 87 Episode: Finished after 84 steps：최근 10 에피소드의 평균 단계 수 = 95.0
# 88 Episode: Finished after 139 steps：최근 10 에피소드의 평균 단계 수 = 103.2
# 89 Episode: Finished after 198 steps：최근 10 에피소드의 평균 단계 수 = 109.7
# 90 Episode: Finished after 115 steps：최근 10 에피소드의 평균 단계 수 = 110.3
# 91 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 116.7
# 92 Episode: Finished after 197 steps：최근 10 에피소드의 평균 단계 수 = 130.1
# 93 Episode: Finished after 150 steps：최근 10 에피소드의 평균 단계 수 = 138.1
# 94 Episode: Finished after 138 steps：최근 10 에피소드의 평균 단계 수 = 144.5
# 95 Episode: Finished after 108 steps：최근 10 에피소드의 평균 단계 수 = 142.6
# 96 Episode: Finished after 176 steps：최근 10 에피소드의 평균 단계 수 = 150.5
# 97 Episode: Finished after 174 steps：최근 10 에피소드의 평균 단계 수 = 159.5
# 98 Episode: Finished after 194 steps：최근 10 에피소드의 평균 단계 수 = 165.0
# 99 Episode: Finished after 152 steps：최근 10 에피소드의 평균 단계 수 = 160.4
# 100 Episode: Finished after 177 steps：최근 10 에피소드의 평균 단계 수 = 166.6
# 101 Episode: Finished after 140 steps：최근 10 에피소드의 평균 단계 수 = 160.6
# 102 Episode: Finished after 169 steps：최근 10 에피소드의 평균 단계 수 = 157.8
# 103 Episode: Finished after 160 steps：최근 10 에피소드의 평균 단계 수 = 158.8
# 104 Episode: Finished after 186 steps：최근 10 에피소드의 평균 단계 수 = 163.6
# 105 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 172.8
# 106 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 175.2
# 107 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 177.8
# 108 Episode: Finished after 186 steps：최근 10 에피소드의 평균 단계 수 = 177.0
# 109 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 181.8
# 110 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 184.1
# 111 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 190.1
# 112 Episode: Finished after 182 steps：최근 10 에피소드의 평균 단계 수 = 191.4
# 113 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 195.4
# 114 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 196.8
# 115 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 196.8
# 116 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 196.8
# 117 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 196.8
# 118 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 198.2
# 119 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 198.2
# 120 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 198.2
# 121 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 198.2
# 122 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 200.0
# 10 에피소드 연속 성공
# 123 Episode: Finished after 200 steps：최근 10 에피소드의 평균 단계 수 = 200.0
